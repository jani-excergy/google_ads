l_4=new_l[240:320]
l_5=new_l[320:400]
l_6=new_l[400:480]
l_7=new_l[480:560]
l_8=new_l[560:640]
l_9=new_l[640:720]
l_10=new_l[720:]

# %%
import pandas as pd
import requests
import json



la_1 = []

for i in l_1:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    a=((lat,lng))
    la_1.append(a)




df_1= pd.DataFrame(la_1,columns=['lat','lng'])
df_1.head()
# Out:
#          lat         lng
# 0  34.479332 -117.397422
# 1  33.963074 -118.274809
# 2  33.711551 -116.236141
# 3  33.601873 -117.866850
# 4  33.638018 -117.088880

# %%
la_2 = []

for i in l_2:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    b=((lat,lng))
    la_2.append(b)




df_2= pd.DataFrame(la_2,columns=['lat','lng'])
df_2.head()
# Out:
#          lat         lng
# 0  33.881275 -117.538285
# 1  33.865783 -118.397272
# 2  34.076460 -118.309453
# 3  33.752825 -117.994896
# 4  33.848002 -116.544736

# %%
la_3 = []

for i in l_3:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    c=((lat,lng))
    la_3.append(c)




df_3= pd.DataFrame(la_3,columns=['lat','lng'])
df_3.head()
# Out:
#          lat         lng
# 0  33.817538 -117.973476
# 1  33.890737 -118.205412
# 2  34.006995 -118.038284
# 3  33.670881 -117.737624
# 4  34.217407 -118.171447

# %%
la_4 = []

for i in l_4:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    d=((lat,lng))
    la_4.append(d)




df_4= pd.DataFrame(la_4,columns=['lat','lng'])
df_4.head()
# Out:
#          lat         lng
# 0  33.876760 -118.286071
# 1  33.664633 -117.176817
# 2  34.225469 -117.323496
# 3  33.998631 -117.970297
# 4  33.817423 -117.810110

# %%
la_5 = []

for i in l_5:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    e=((lat,lng))
    la_5.append(e)




df_5= pd.DataFrame(la_5,columns=['lat','lng'])
df_5.head()
# Out:
#          lat         lng
# 0  33.630348 -117.585350
# 1  34.055011 -117.313560
# 2  33.694507 -117.662787
# 3  33.667231 -117.968323
# 4  33.641996 -117.841328

# %%
la_6 = []

for i in l_6:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    f=((lat,lng))
    la_6.append(f)




df_6= pd.DataFrame(la_6,columns=['lat','lng'])
df_6.head()
# Out:
#          lat         lng
# 0  33.891810 -118.296621
# 1  34.033089 -117.033519
# 2  33.924110 -116.883374
# 3  33.688992 -117.787794
# 4  33.817538 -117.973476

# %%
la_7 = []

for i in l_7:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    g=((lat,lng))
    la_7.append(g)




df_7= pd.DataFrame(la_7,columns=['lat','lng'])
df_7.head()
# Out:
#          lat         lng
# 0  34.198683 -118.658084
# 1  33.721286 -118.044372
# 2  33.995229 -117.535073
# 3  33.630348 -117.585350
# 4  33.817538 -117.973476

# %%
la_8 = []

for i in l_8:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    h=((lat,lng))
    la_8.append(h)




df_8= pd.DataFrame(la_8,columns=['lat','lng'])
df_8.head()
# Out:
#          lat         lng
# 0  33.972442 -117.726974
# 1  34.131219 -117.464097
# 2  33.992817 -118.373557
# 3  33.840909 -118.079698
# 4  33.530495 -117.702838

# %%
la_9 = []

for i in l_9:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    i=((lat,lng))
    la_9.append(i)




df_9= pd.DataFrame(la_9,columns=['lat','lng'])
df_9.head()
# Out:
#          lat         lng
# 0  33.692651 -117.248892
# 1  33.718132 -118.071196
# 2  34.055011 -117.313560
# 3  34.109642 -118.226785
# 4  33.923668 -117.553508

# %%
la_10 = []

for i in l_10:

    zip_add= (i)

    parm= {"key": "XArrqUOMgV9ZdW9fks4PAq5Nn6pcArKg",
           "location":zip_add}
    res= requests.get("http://www.mapquestapi.com/geocoding/v1/address",params= parm)

    dat= json.loads(res.text)['results']



    lat=dat[0]['locations'][0]['latLng']['lat']
    lng=dat[0]['locations'][0]['latLng']['lng']

    j=((lat,lng))
    la_10.append(j)




df_10= pd.DataFrame(la_10,columns=['lat','lng'])
df_10.head()
# Out:
#          lat         lng
# 0  33.664633 -117.176817
# 1  34.232387 -118.247355
# 2  33.843645 -118.011847
# 3  34.135112 -118.029184
# 4  34.019668 -117.856008

# %%
df_10.shape
# Out:
# (38, 2)

# %%
fi= [df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10]

# %%
zip_cor= pd.concat(fi,ignore_index=True)

# %%
zip_cor.tail()
# Out:
#            lat         lng
# 753  33.692651 -117.248892
# 754  33.758511 -118.363978
# 755  33.923893 -118.201293
# 756  33.646667 -117.917058
# 757  34.255322 -118.423060

# %%
cle= pd.read_csv('fine.csv')

# %%
cle.shape
# Out:
# (758, 16)

# %%
zip_cor['Day']= cle['Day']

# %%
zip_cor.shape
# Out:
# (758, 3)

# %%
zip_cor.head()
# Out:
#          lat         lng         Day
# 0  34.479332 -117.397422  2019-01-02
# 1  33.963074 -118.274809  2019-01-03
# 2  33.711551 -116.236141  2019-01-04
# 3  33.601873 -117.866850  2019-01-05
# 4  33.638018 -117.088880  2019-01-06

# %%
cle.shape
# Out:
# (758, 16)

# %%
zip_cor.shape
# Out:
# (758, 3)

# %%
cle.head()
# Out:
#    Unnamed: 0         Day Day of week     Cost  Impressions  Clicks     CTR  \
# 0           0  2019-01-02   Wednesday  1298.05        44533      54  0.0012
# 1           1  2019-01-03    Thursday  1480.26         2221      59  0.0266
# 2           2  2019-01-04      Friday  1953.52        36095     110  0.0030
# 3           3  2019-01-05    Saturday  2507.57        18171     123  0.0068
# 4           4  2019-01-06      Sunday  1591.91        15185      88  0.0058
#
#    Avg. CPC  Conversions  Conv. rate  Cost / conv. Search Impr. share  \
# 0     24.04         15.0      0.0540         86.54               0.35
# 1     25.09         10.1      0.1712        146.56             0.5233
# 2     17.76         22.0      0.0295         85.93             0.6041
# 3     20.39         29.5      0.0127         85.00             0.7161
# 4     18.09         16.5      0.0087         96.48             0.7447
#
#   Search Lost IS (rank) Search Lost IS (budget)    Zip    Income
# ...

# %%
cle=cle.drop(['Unnamed: 0'],axis=1)

# %%
cle.head()
# Out:
#           Day Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0  2019-01-02   Wednesday  1298.05        44533      54  0.0012     24.04
# 1  2019-01-03    Thursday  1480.26         2221      59  0.0266     25.09
# 2  2019-01-04      Friday  1953.52        36095     110  0.0030     17.76
# 3  2019-01-05    Saturday  2507.57        18171     123  0.0068     20.39
# 4  2019-01-06      Sunday  1591.91        15185      88  0.0058     18.09
#
#    Conversions  Conv. rate  Cost / conv. Search Impr. share  \
# 0         15.0      0.0540         86.54               0.35
# 1         10.1      0.1712        146.56             0.5233
# 2         22.0      0.0295         85.93             0.6041
# 3         29.5      0.0127         85.00             0.7161
# 4         16.5      0.0087         96.48             0.7447
#
#   Search Lost IS (rank) Search Lost IS (budget)    Zip    Income
# 0                0.0935                  0.5565  92392  104993.5
# ...

# %%
cle.shape
# Out:
# (758, 15)

# %%
zip_cor.shape
# Out:
# (758, 3)

# %%
zip_cor.head()
# Out:
#          lat         lng         Day
# 0  34.479332 -117.397422  2019-01-02
# 1  33.963074 -118.274809  2019-01-03
# 2  33.711551 -116.236141  2019-01-04
# 3  33.601873 -117.866850  2019-01-05
# 4  33.638018 -117.088880  2019-01-06

# %%
zip_cor=zip_cor.drop(['Day'],axis=1)

# %%
zip_cor.shape
# Out:
# (758, 2)

# %%
zip_cor
# Out:
#            lat         lng
# 0    34.479332 -117.397422
# 1    33.963074 -118.274809
# 2    33.711551 -116.236141
# 3    33.601873 -117.866850
# 4    33.638018 -117.088880
# 5    34.226115 -118.368817
# 6    33.787270 -117.978971
# 7    33.936850 -117.952050
# 8    33.721286 -118.044372
# 9    33.752825 -117.994896
# 10   33.944167 -117.992404
# 11   33.841170 -117.722650
# 12   34.156928 -118.600438
# 13   34.071744 -117.698448
# 14   33.544915 -117.773786
# 15   34.056930 -118.794997
# 16   33.903240 -117.456053
# 17   33.955791 -118.308916
# 18   34.115224 -118.191967
# 19   33.988604 -118.335291
# 20   33.662262 -117.826486
# 21   33.971609 -118.171234
# 22   33.881785 -117.855290
# 23   33.983714 -117.899050
# 24   34.060998 -118.538301
# 25   33.956998 -118.358491
# 26   34.191995 -118.138697
# 27   33.795998 -118.117913
# 28   34.051963 -118.383981
# 29   33.763737 -116.327275
# ..         ...         ...
# 728  33.974632 -117.331548
# 729  33.914594 -118.350791
# ...

# %%
cle
# Out:
#             Day Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0    2019-01-02   Wednesday  1298.05        44533      54  0.0012     24.04
# 1    2019-01-03    Thursday  1480.26         2221      59  0.0266     25.09
# 2    2019-01-04      Friday  1953.52        36095     110  0.0030     17.76
# 3    2019-01-05    Saturday  2507.57        18171     123  0.0068     20.39
# 4    2019-01-06      Sunday  1591.91        15185      88  0.0058     18.09
# 5    2019-01-07      Monday  2491.86        14286     136  0.0095     18.32
# 6    2019-01-08     Tuesday  1914.45        12733      93  0.0073     20.59
# 7    2019-01-09   Wednesday  1695.57        18424      90  0.0049     18.84
# 8    2019-01-10    Thursday  1293.04        16904      78  0.0046     16.58
# 9    2019-01-11      Friday  1562.85        18966      94  0.0050     16.63
# 10   2019-01-12    Saturday  1432.75        46535     119  0.0026     12.04
# ...

# %%
end_1 = pd.concat([cle,zip_cor],axis=1)

# %%
end_1.shape
# Out:
# (758, 17)

# %%
end_1.head(10)
# Out:
#           Day  Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0  2019-01-02            2  1298.05        44533      54  0.0012     24.04
# 1  2019-01-03            3  1480.26         2221      59  0.0266     25.09
# 2  2019-01-04            4  1953.52        36095     110  0.0030     17.76
# 3  2019-01-05            5  2507.57        18171     123  0.0068     20.39
# 4  2019-01-06            6  1591.91        15185      88  0.0058     18.09
# 5  2019-01-07            0  2491.86        14286     136  0.0095     18.32
# 6  2019-01-08            1  1914.45        12733      93  0.0073     20.59
# 7  2019-01-09            2  1695.57        18424      90  0.0049     18.84
# 8  2019-01-10            3  1293.04        16904      78  0.0046     16.58
# 9  2019-01-11            4  1562.85        18966      94  0.0050     16.63
#
#    Conversions  Conv. rate  Cost / conv. Search Impr. share  \
# 0         15.0      0.0540         86.54               0.35
# ...

# %%
end_1.dtypes
# Out:
# Day                         object
# Day of week                 object
# Cost                       float64
# Impressions                  int64
# Clicks                       int64
# CTR                        float64
# Avg. CPC                   float64
# Conversions                float64
# Conv. rate                 float64
# Cost / conv.               float64
# Search Impr. share          object
# Search Lost IS (rank)       object
# Search Lost IS (budget)     object
# Zip                          int64
# Income                     float64
# lat                        float64
# lng                        float64
# dtype: object

# %%
end_1['Day of week']=end_1['Day of week'].replace('Monday',0)
end_1['Day of week']=end_1['Day of week'].replace('Tuesday',1)
end_1['Day of week']=end_1['Day of week'].replace('Wednesday',2)
end_1['Day of week']=end_1['Day of week'].replace('Thursday',3)
end_1['Day of week']=end_1['Day of week'].replace('Friday',4)
end_1['Day of week']=end_1['Day of week'].replace('Saturday',5)
end_1['Day of week']=end_1['Day of week'].replace('Sunday',6)

# %%
end_1.head()
# Out:
#           Day  Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0  2019-01-02            2  1298.05        44533      54  0.0012     24.04
# 1  2019-01-03            3  1480.26         2221      59  0.0266     25.09
# 2  2019-01-04            4  1953.52        36095     110  0.0030     17.76
# 3  2019-01-05            5  2507.57        18171     123  0.0068     20.39
# 4  2019-01-06            6  1591.91        15185      88  0.0058     18.09
#
#    Conversions  Conv. rate  Cost / conv. Search Impr. share  \
# 0         15.0      0.0540         86.54               0.35
# 1         10.1      0.1712        146.56             0.5233
# 2         22.0      0.0295         85.93             0.6041
# 3         29.5      0.0127         85.00             0.7161
# 4         16.5      0.0087         96.48             0.7447
#
#   Search Lost IS (rank) Search Lost IS (budget)    Zip    Income        lat  \
# ...

# %%
import numpy as np

# %%
end_1['Search Impr. share'].unique()
# Out:
# array(['0.35', '0.5233', '0.6041', '0.7161', '0.7447', '0.6444', '0.6478',
#        '0.6471', '0.6469', '0.6405', '0.6445', '0.7301', '0.6737',
#        '0.6752', '0.6427', '0.6472', '0.6604', '0.7163', '0.7355',
#        '0.6349', '0.6441', '0.6322', '0.4697', '0.5069', '0.7131',
#        '0.7264', '0.6218', '0.6813', '0.6843', '0.7329', '0.6897',
#        '0.8213', '0.8144', '0.7317', '0.7344', '0.7198', '0.7078',
#        '0.6499', '0.5658', '0.6666', '0.4609', '0.6001', '0.5847',
#        '0.6423', '0.7321', '0.7558', '0.7928', '0.7437', '0.7504',
#        '0.7376', '0.7378', '0.7603', '0.8679', '0.8236', '0.6949',
#        '0.4772', '0.6033', '0.6163', '0.5914', '0.7005', '0.7925',
#        '0.6533', '0.5656', '0.4927', '0.6084', '0.6491', '0.7368',
#        '0.6851', '0.633', '0.6528', '0.6129', '0.537', '0.5408', '0.7247',
#        '0.7424', '0.6011', '0.6613', '0.6473', '0.663', '0.6574',
#        '0.7028', '0.7718', '0.6937', '0.6996', '0.6822', '0.7103',
# ...

# %%
end_1['Search Impr. share']=end_1['Search Impr. share'].replace('<10%',0.09)
end_1['Search Impr. share']=end_1['Search Impr. share'].replace(' --',0.09)
end_1['Search Lost IS (rank)']=end_1['Search Lost IS (rank)'].replace(' --',0.05)
end_1['Search Lost IS (budget)']=end_1['Search Lost IS (budget)'].replace(' --',0.5)

# %%
end_1['Search Impr. share']=end_1['Search Impr. share'].astype(np.float64)
end_1['Search Lost IS (rank)']=end_1['Search Lost IS (rank)'].astype(np.float64)
end_1['Search Lost IS (budget)']=end_1['Search Lost IS (budget)'].astype(np.float64)

# %%
end_1['Search Impr. share'].dtype
# Out:
# dtype('float64')

# %%
np.isnan(end_1['Search Impr. share']).sum()
# Out:
# 0

# %%
np.isnan(end_1['Search Lost IS (rank)']).sum()
# Out:
# 0

# %%
end_1.dtypes
# Out:
# Day                         object
# Day of week                  int64
# Cost                       float64
# Impressions                  int64
# Clicks                       int64
# CTR                        float64
# Avg. CPC                   float64
# Conversions                float64
# Conv. rate                 float64
# Cost / conv.               float64
# Search Impr. share         float64
# Search Lost IS (rank)      float64
# Search Lost IS (budget)    float64
# Zip                          int64
# Income                     float64
# lat                        float64
# lng                        float64
# dtype: object

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.pairplot(end_1)

# %%
inde= end_1.drop(['Income','Zip'],axis=1)

# %%
inde.head()
# Out:
#           Day  Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0  2019-01-02            2  1298.05        44533      54  0.0012     24.04
# 1  2019-01-03            3  1480.26         2221      59  0.0266     25.09
# 2  2019-01-04            4  1953.52        36095     110  0.0030     17.76
# 3  2019-01-05            5  2507.57        18171     123  0.0068     20.39
# 4  2019-01-06            6  1591.91        15185      88  0.0058     18.09
#
#    Conversions  Conv. rate  Cost / conv.  Search Impr. share  \
# 0         15.0      0.0540         86.54              0.3500
# 1         10.1      0.1712        146.56              0.5233
# 2         22.0      0.0295         85.93              0.6041
# 3         29.5      0.0127         85.00              0.7161
# 4         16.5      0.0087         96.48              0.7447
#
#    Search Lost IS (rank)  Search Lost IS (budget)        lat         lng
# 0                 0.0935                   0.5565  34.479332 -117.397422
# ...

# %%
plt.figure(figsize=(20,10))

sns.heatmap(inde.corr(),annot=True,yticklabels=True)

# %%
c= end_1.drop(['Conversions','Zip','Impressions'],axis=1)

# %%
c.head()
# Out:
#           Day  Day of week     Cost  Clicks     CTR  Avg. CPC  Conv. rate  \
# 0  2019-01-02            2  1298.05      54  0.0012     24.04      0.0540
# 1  2019-01-03            3  1480.26      59  0.0266     25.09      0.1712
# 2  2019-01-04            4  1953.52     110  0.0030     17.76      0.0295
# 3  2019-01-05            5  2507.57     123  0.0068     20.39      0.0127
# 4  2019-01-06            6  1591.91      88  0.0058     18.09      0.0087
#
#    Cost / conv.  Search Impr. share  Search Lost IS (rank)  \
# 0         86.54              0.3500                 0.0935
# 1        146.56              0.5233                 0.1120
# 2         85.93              0.6041                 0.2028
# 3         85.00              0.7161                 0.1884
# 4         96.48              0.7447                 0.2129
#
#    Search Lost IS (budget)    Income        lat         lng
# 0                   0.5565  104993.5  34.479332 -117.397422
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(c.corr(),annot=True)

# %%
new_df= end_1.copy()

# %%
new_df.shape
# Out:
# (758, 17)

# %%
new_df.head()
# Out:
#           Day  Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0  2019-01-02            2  1298.05        44533      54  0.0012     24.04
# 1  2019-01-03            3  1480.26         2221      59  0.0266     25.09
# 2  2019-01-04            4  1953.52        36095     110  0.0030     17.76
# 3  2019-01-05            5  2507.57        18171     123  0.0068     20.39
# 4  2019-01-06            6  1591.91        15185      88  0.0058     18.09
#
#    Conversions  Conv. rate  Cost / conv.  Search Impr. share  \
# 0         15.0      0.0540         86.54              0.3500
# 1         10.1      0.1712        146.56              0.5233
# 2         22.0      0.0295         85.93              0.6041
# 3         29.5      0.0127         85.00              0.7161
# 4         16.5      0.0087         96.48              0.7447
#
#    Search Lost IS (rank)  Search Lost IS (budget)    Zip    Income        lat  \
# ...

# %%
new_df['Day']=pd.to_datetime(new_df['Day'],infer_datetime_format=True)

# %%
new_df.dtypes
# Out:
# Day                        datetime64[ns]
# Day of week                         int64
# Cost                              float64
# Impressions                         int64
# Clicks                              int64
# CTR                               float64
# Avg. CPC                          float64
# Conversions                       float64
# Conv. rate                        float64
# Cost / conv.                      float64
# Search Impr. share                float64
# Search Lost IS (rank)             float64
# Search Lost IS (budget)           float64
# Zip                                 int64
# Income                            float64
# lat                               float64
# lng                               float64
# dtype: object

# %%
new_df["day"] = pd.to_datetime(new_df.Day, format="%y/%m/%d").dt.day
new_df["month"] = pd.to_datetime(new_df.Day, format="%y/%m/%d").dt.month
new_df["year"] = pd.to_datetime(new_df.Day, format="%y/%m/%d").dt.year

# %%
new_df.head()
# Out:
#          Day  Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  \
# 0 2019-01-02            2  1298.05        44533      54  0.0012     24.04
# 1 2019-01-03            3  1480.26         2221      59  0.0266     25.09
# 2 2019-01-04            4  1953.52        36095     110  0.0030     17.76
# 3 2019-01-05            5  2507.57        18171     123  0.0068     20.39
# 4 2019-01-06            6  1591.91        15185      88  0.0058     18.09
#
#    Conversions  Conv. rate  Cost / conv.  Search Impr. share  \
# 0         15.0      0.0540         86.54              0.3500
# 1         10.1      0.1712        146.56              0.5233
# 2         22.0      0.0295         85.93              0.6041
# 3         29.5      0.0127         85.00              0.7161
# 4         16.5      0.0087         96.48              0.7447
#
#    Search Lost IS (rank)  Search Lost IS (budget)    Zip    Income        lat  \
# ...

# %%
new_df=new_df.drop(['Conversions','Impressions'],axis=1)

# %%
new_df=new_df.drop(['Zip'],axis=1)

# %%
new_df.head()
# Out:
#    Day of week     Cost  Clicks     CTR  Avg. CPC  Conv. rate  Cost / conv.  \
# 0            2  1298.05      54  0.0012     24.04      0.0540         86.54
# 1            3  1480.26      59  0.0266     25.09      0.1712        146.56
# 2            4  1953.52     110  0.0030     17.76      0.0295         85.93
# 3            5  2507.57     123  0.0068     20.39      0.0127         85.00
# 4            6  1591.91      88  0.0058     18.09      0.0087         96.48
#
#    Search Impr. share  Search Lost IS (rank)  Search Lost IS (budget)  \
# 0              0.3500                 0.0935                   0.5565
# 1              0.5233                 0.1120                   0.3647
# 2              0.6041                 0.2028                   0.1931
# 3              0.7161                 0.1884                   0.0955
# 4              0.7447                 0.2129                   0.0424
#
#      Income        lat         lng  day  month  year
# ...

# %%
y= new_df['Income']

# %%
X=new_df.drop(['Income'],axis=1)

# %%
X.head()
# Out:
#    Day of week     Cost  Clicks     CTR  Avg. CPC  Conv. rate  Cost / conv.  \
# 0            2  1298.05      54  0.0012     24.04      0.0540         86.54
# 1            3  1480.26      59  0.0266     25.09      0.1712        146.56
# 2            4  1953.52     110  0.0030     17.76      0.0295         85.93
# 3            5  2507.57     123  0.0068     20.39      0.0127         85.00
# 4            6  1591.91      88  0.0058     18.09      0.0087         96.48
#
#    Search Impr. share  Search Lost IS (rank)  Search Lost IS (budget)  \
# 0              0.3500                 0.0935                   0.5565
# 1              0.5233                 0.1120                   0.3647
# 2              0.6041                 0.2028                   0.1931
# 3              0.7161                 0.1884                   0.0955
# 4              0.7447                 0.2129                   0.0424
#
#          lat         lng  day  month  year
# 0  34.479332 -117.397422    2      1  2019
# ...

# %%
y
# Out:
# 0      104993.50
# 1       40865.20
# 2       91188.00
# 3       55627.00
# 4       12713.00
# 5      112489.00
# 6       86987.40
# 7       53727.00
# 8      122267.35
# 9       41135.00
# 10      29590.00
# 11      32574.00
# 12     101913.00
# 13      47706.00
# 14      57478.72
# 15      77626.00
# 16      70872.00
# 17      80865.00
# 18        512.50
# 19      85873.00
# 20     100443.00
# 21     114692.00
# 22      44019.00
# 23      81309.35
# 24      48007.00
# 25       2981.00
# 26     101558.00
# 27      55277.20
# 28      30870.65
# 29      55521.00
#          ...
# 728     92859.82
# 729     16559.51
# 730     16559.51
# 731      3340.15
# 732    161384.47
# 733    104197.05
# 734     56781.01
# 735     81408.46
# 736     44717.10
# 737     27336.43
# 738      2266.00
# 739    125531.93
# 740     92009.72
# 741    106314.55
# 742    123513.20
# 743    118470.25
# 744    118470.25
# 745     15575.98
# 746      4392.75
# 747    123982.79
# 748    117615.79
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
new_df.shape
# Out:
# (758, 16)

# %%
train = new_df[:710]

# %%
train.shape
# Out:
# (710, 16)

# %%
test= new_df[710:]

# %%
test.shape
# Out:
# (48, 16)

# %%
X_1= train.drop(['Income'],axis=1)

# %%
X_1.shape
# Out:
# (710, 15)

# %%
y_1=train['Income']

# %%
y_1
# Out:
# 0      104993.50
# 1       40865.20
# 2       91188.00
# 3       55627.00
# 4       12713.00
# 5      112489.00
# 6       86987.40
# 7       53727.00
# 8      122267.35
# 9       41135.00
# 10      29590.00
# 11      32574.00
# 12     101913.00
# 13      47706.00
# 14      57478.72
# 15      77626.00
# 16      70872.00
# 17      80865.00
# 18        512.50
# 19      85873.00
# 20     100443.00
# 21     114692.00
# 22      44019.00
# 23      81309.35
# 24      48007.00
# 25       2981.00
# 26     101558.00
# 27      55277.20
# 28      30870.65
# 29      55521.00
#          ...
# 680     98476.94
# 681     70429.33
# 682     76378.19
# 683     36660.10
# 684      2393.74
# 685    131200.19
# 686     67600.63
# 687     55082.74
# 688         0.00
# 689     47179.54
# 690     63148.38
# 691      6262.00
# 692    159067.47
# 693     67585.78
# 694    119116.20
# 695    120018.80
# 696     84704.22
# 697     76250.57
# 698      1177.00
# 699    207610.41
# 700     78252.22
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_1, y_1, test_size = 0.2, random_state =0)

# %%
X_train.shape,y_train.shape
# Out:
# ((568, 15), (568,))

# %%
from sklearn.ensemble import RandomForestRegressor

random_forest_reg=RandomForestRegressor()

# %%
random_forest_reg.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
random_forest_reg.score(X_train,y_train)
# Out:
# 0.9460279568470649

# %%
random_forest_reg.score(X_test,y_test)
# Out:
# 0.5566007566324276

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(random_forest_reg, X_1, y_1, cv=5)

# %%
score.mean()
# Out:
# 0.35586793577464737

# %%
from sklearn.model_selection import RandomizedSearchCV

from scipy.stats import randint


parameters = {'n_estimators': randint(100,1200),
               'max_features': ['auto','sqrt'],
               'max_depth': randint(5,40),
               'min_samples_split': randint(2,30),
               'min_samples_leaf': randint(1,10)  }

# %%
base_learner=RandomForestRegressor()

# %%
tuned_model= RandomizedSearchCV(estimator = base_learner, param_distributions = parameters,scoring='neg_mean_squared_error', n_iter = 100, cv = 5, verbose=2, random_state=42)

# %%
tuned_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=33, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=221; total time=   0.5s
# [CV] END max_depth=33, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=221; total time=   0.4s
# [CV] END max_depth=33, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=221; total time=   0.4s
# [CV] END max_depth=33, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=221; total time=   0.4s
# [CV] END max_depth=33, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=221; total time=   0.4s
# [CV] END max_depth=23, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=971; total time=   2.1s
# [CV] END max_depth=23, max_features=auto, min_samples_leaf=8, min_samples_split=22, n_estimators=971; total time=   2.1s
# ...

# %%
tuned_model.best_params_
# Out:
# {'max_depth': 15,
#  'max_features': 'auto',
#  'min_samples_leaf': 1,
#  'min_samples_split': 9,
#  'n_estimators': 518}

# %%
tuned_model.best_score_
# Out:
# -1657122330.159818

# %%
prediction=tuned_model.predict(X_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 37775.5985572923
# MSE: 2610089085.2895894
# RMSE: 51089.03096839467

# %%
new_df.columns
# Out:
# Index(['Day of week', 'Cost', 'Clicks', 'CTR', 'Avg. CPC', 'Conv. rate',
#        'Cost / conv.', 'Search Impr. share', 'Search Lost IS (rank)',
#        'Search Lost IS (budget)', 'Income', 'lat', 'lng', 'day', 'month',
#        'year'],
#       dtype='object')

# %%
for i in new_df.columns:
    sns.distplot(new_df['Day of week'])

# %%
end_1.shape
# Out:
# (758, 17)

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model1= ExtraTreesRegressor()
model1.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
feat_importances = pd.Series(model1.feature_importances_, index=X.columns)
feat_importances.nlargest(20).plot(kind='barh')
plt.show()

# %%
end_1.to_excel('final.xlsx')

# %% [markdown]
# # Time Series analysis

# %%
import tensorflow as tf
# Out:
# C:\Users\vksva\Anaconda3\lib\site-packages\h5py\__init__.py:40: UserWarning: h5py is running against HDF5 1.10.5 when it was built against 1.10.4, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
