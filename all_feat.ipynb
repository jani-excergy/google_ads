# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('final_feat.xlsx')

# %%
df.head()
# Out:
#   Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  Conversions  \
# 0    Thursday  3181.56        13361     156  0.0117     20.39        26.77
# 1      Friday  2684.67        16841     160  0.0095     16.78        21.00
# 2    Saturday  1338.36        30788     142  0.0046      9.43        11.00
# 3      Sunday  1192.31        12865     108  0.0084     11.04         5.00
# 4      Monday  2383.17        49514     188  0.0038     12.68        22.00
#
#    Conv. rate  Cost / conv. Search Impr. share  ...  Total Jobs   Avg Service  \
# 0      0.0486        118.86             0.5337  ...          101   143.417833
# 1      0.0299        127.84             0.5477  ...           89    75.515208
# 2      0.0186        121.67             0.5297  ...           31   110.019048
# 3      0.0130        238.46             0.5741  ...           15    67.914286
# 4      0.0566        108.33             0.6027  ...           91    78.753750
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(method='spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %%
# converting categorical features into numerical values 
df['Day of week']=df['Day of week'].replace('Monday',0)
df['Day of week']=df['Day of week'].replace('Tuesday',1)
df['Day of week']=df['Day of week'].replace('Wednesday',2)
df['Day of week']=df['Day of week'].replace('Thursday',3)
df['Day of week']=df['Day of week'].replace('Friday',4)
df['Day of week']=df['Day of week'].replace('Saturday',5)
df['Day of week']=df['Day of week'].replace('Sunday',6)

# %%
df.head()
# Out:
#    Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  Conversions  \
# 0            3  3181.56        13361     156  0.0117     20.39        26.77
# 1            4  2684.67        16841     160  0.0095     16.78        21.00
# 2            5  1338.36        30788     142  0.0046      9.43        11.00
# 3            6  1192.31        12865     108  0.0084     11.04         5.00
# 4            0  2383.17        49514     188  0.0038     12.68        22.00
#
#    Conv. rate  Cost / conv. Search Impr. share  ...  Total Jobs   Avg Service  \
# 0      0.0486        118.86             0.5337  ...          101   143.417833
# 1      0.0299        127.84             0.5477  ...           89    75.515208
# 2      0.0186        121.67             0.5297  ...           31   110.019048
# 3      0.0130        238.46             0.5741  ...           15    67.914286
# 4      0.0566        108.33             0.6027  ...           91    78.753750
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(method='spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %%
df['Income_x']
# Out:
# 0      137581.58
# 1       43204.73
# 2       14709.40
# 3        3725.40
# 4       74598.75
#          ...
# 345      3638.60
# 346    105791.21
# 347    108946.38
# 348    152179.88
# 349     62872.40
# Name: Income_x, Length: 350, dtype: float64

# %%
df['Income_y']
# Out:
# 0       23933.54
# 1       65232.03
# 2       26195.32
# 3         264.00
# 4       48506.16
#          ...
# 345     55111.85
# 346    133042.85
# 347     88538.89
# 348     66133.39
# 349     67090.81
# Name: Income_y, Length: 350, dtype: float64

# %%
df['day_of_week_sin'] = np.sin(2 * np.pi * df['Day of week']/6.0)
df['day_of_week_cos'] = np.cos(2 * np.pi * df['Day of week']/6.0)

# %%
df.head()
# Out:
#    Day of week     Cost  Impressions  Clicks     CTR  Avg. CPC  Conversions  \
# 0            3  3181.56        13361     156  0.0117     20.39        26.77
# 1            4  2684.67        16841     160  0.0095     16.78        21.00
# 2            5  1338.36        30788     142  0.0046      9.43        11.00
# 3            6  1192.31        12865     108  0.0084     11.04         5.00
# 4            0  2383.17        49514     188  0.0038     12.68        22.00
#
#    Conv. rate  Cost / conv. Search Impr. share  ...  Avg Install  \
# 0      0.0486        118.86             0.5337  ...  3224.412750
# 1      0.0299        127.84             0.5477  ...   965.365854
# 2      0.0186        121.67             0.5297  ...  1377.666667
# 3      0.0130        238.46             0.5741  ...   406.250000
# 4      0.0566        108.33             0.6027  ...  1646.943488
#
#    Canceled Jobs_y Turn over %  Canceled %    Avg Sales bookedjob  totalcalls  \
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(method='spearman'),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Day of week', 'Cost', 'Impressions', 'Clicks', 'CTR', 'Avg. CPC',
#        'Conversions', 'Conv. rate', 'Cost / conv.', 'Search Impr. share',
#        'Search Lost IS (rank)', 'Search Lost IS (budget)', 'Created Date',
#        'Location Zip_x', 'Income_x', 'Year Month', 'Completed Jobs',
#        'Income_y', 'Lead Calls', 'Canceled Jobs_x', 'Future Scheduled Jobs',
#        'Location Zip_y', 'tech_count', 'Avg_job_per_day', 'county_name',
#        'TMAX', 'TMIN', 'Total Leads', 'Total Jobs ', 'Avg Service',
#        'Avg Install', 'Canceled Jobs_y', 'Turn over %', 'Canceled %',
#        'Avg Sales', 'bookedjob', 'totalcalls', 'Booking rate',
#        'day_of_week_sin', 'day_of_week_cos'],
#       dtype='object')

# %%
df1=df[[ 'Cost', 'Impressions', 'Clicks', 'CTR', 'Avg. CPC',
       'Conversions', 'Conv. rate', 'Cost / conv.', 'Search Impr. share',
       'Search Lost IS (rank)', 'Search Lost IS (budget)',
         'Completed Jobs',
       'Income_y', 'Lead Calls',
       'Location Zip_y', 'tech_count', 'Avg_job_per_day', 'county_name',
       'TMAX', 'TMIN', 'Total Leads', 'Total Jobs ', 'Avg Service',
       'Avg Install', 'Canceled Jobs_y', 'Turn over %', 'Canceled %',
       'Avg Sales', 'bookedjob', 'totalcalls', 'Booking rate']]

# %%
df1.head()
# Out:
#       Cost  Impressions  Clicks     CTR  Avg. CPC  Conversions  Conv. rate  \
# 0  3181.56        13361     156  0.0117     20.39        26.77      0.0486
# 1  2684.67        16841     160  0.0095     16.78        21.00      0.0299
# 2  1338.36        30788     142  0.0046      9.43        11.00      0.0186
# 3  1192.31        12865     108  0.0084     11.04         5.00      0.0130
# 4  2383.17        49514     188  0.0038     12.68        22.00      0.0566
#
#    Cost / conv. Search Impr. share  Search Lost IS (rank)  ...  Total Jobs   \
# 0        118.86             0.5337                 0.2676  ...          101
# 1        127.84             0.5477                 0.3122  ...           89
# 2        121.67             0.5297                 0.3158  ...           31
# 3        238.46             0.5741                 0.3349  ...           15
# 4        108.33             0.6027                 0.3596  ...           91
#
# ...

# %%
df1['county_name']=pd.get_dummies(df1['county_name'],drop_first=True)
# Out:
# C:\Users\vksva\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['Search Impr. share'].unique()
# Out:
# array([0.5337, 0.5477, 0.5297, 0.5741, 0.6027, 0.5845, 0.6019, 0.5941,
#        0.6009, 0.6413, 0.701, 0.7194, 0.7029, 0.698, 0.6995, 0.7157,
#        0.6511, 0.6551, 0.6206, 0.6813, 0.62, 0.6298, 0.6289, 0.6172,
#        0.5682, 0.606, 0.5505, 0.5767, 0.6513, 0.6267, 0.6988, 0.6753,
#        0.6749, 0.6731, 0.6333, 0.6246, 0.691, 0.6716, 0.6692, 0.6604,
#        0.6213, 0.6354, 0.7005, 0.6283, 0.5563, 0.5716, 0.5786, 0.5648,
#        0.6155, 0.5349, 0.4925, 0.5829, 0.4997, 0.5096, 0.5751, 0.6229,
#        0.6357, 0.6216, 0.6154, 0.6337, 0.5858, 0.5935, 0.6328, 0.5372,
#        0.5967, 0.5892, 0.6128, 0.4932, 0.4638, 0.3007, 0.3531, 0.3592,
#        0.3859, 0.372, 0.3365, 0.4096, 0.424, 0.5107, 0.518, 0.5322,
#        0.5174, 0.4873, 0.4944, 0.5616, 0.5147, 0.5226, 0.5403, 0.5674,
#        0.5326, 0.5663, 0.5306, 0.5021, 0.5859, 0.4489, 0.4287, 0.478,
#        0.464, 0.51, 0.4073, 0.3229, 0.2762, 0.309, 0.3336, 0.3364, 0.3755,
# ...

# %%
df['Search Impr. share']=df['Search Impr. share'].replace('<10%',0.09)

# %%
y=df1['Income_y']
X=df1.drop(['Income_y'],axis=1)

# %%
X.head()
# Out:
#       Cost  Impressions  Clicks     CTR  Avg. CPC  Conversions  Conv. rate  \
# 0  3181.56        13361     156  0.0117     20.39        26.77      0.0486
# 1  2684.67        16841     160  0.0095     16.78        21.00      0.0299
# 2  1338.36        30788     142  0.0046      9.43        11.00      0.0186
# 3  1192.31        12865     108  0.0084     11.04         5.00      0.0130
# 4  2383.17        49514     188  0.0038     12.68        22.00      0.0566
#
#    Cost / conv. Search Impr. share  Search Lost IS (rank)  ...  Total Jobs   \
# 0        118.86             0.5337                 0.2676  ...          101
# 1        127.84             0.5477                 0.3122  ...           89
# 2        121.67             0.5297                 0.3158  ...           31
# 3        238.46             0.5741                 0.3349  ...           15
# 4        108.33             0.6027                 0.3596  ...           91
#
# ...

# %%
y
# Out:
# 0       23933.54
# 1       65232.03
# 2       26195.32
# 3         264.00
# 4       48506.16
#          ...
# 345     55111.85
# 346    133042.85
# 347     88538.89
# 348     66133.39
# 349     67090.81
# Name: Income_y, Length: 350, dtype: float64

# %%
X.shape
# Out:
# (350, 30)

# %%
X.isnull().sum()
# Out:
# Cost                       0
# Impressions                0
# Clicks                     0
# CTR                        0
# Avg. CPC                   0
# Conversions                0
# Conv. rate                 0
# Cost / conv.               0
# Search Impr. share         0
# Search Lost IS (rank)      0
# Search Lost IS (budget)    0
# Completed Jobs             0
# Lead Calls                 0
# Location Zip_y             0
# tech_count                 0
# Avg_job_per_day            0
# county_name                0
# TMAX                       0
# TMIN                       0
# Total Leads                0
# Total Jobs                 0
# Avg Service                0
# Avg Install                1
# Canceled Jobs_y            0
# Turn over %                0
# Canceled %                 0
# Avg Sales                  0
# bookedjob                  0
# totalcalls                 0
# Booking rate               0
# dtype: int64

# %%
X['Avg Install']=X['Avg Install'].fillna(1712.5)

# %%
y.isnull().sum()
# Out:
# 0

# %%
X['Search Impr. share'].unique()
# Out:
# array([0.5337, 0.5477, 0.5297, 0.5741, 0.6027, 0.5845, 0.6019, 0.5941,
#        0.6009, 0.6413, 0.701, 0.7194, 0.7029, 0.698, 0.6995, 0.7157,
#        0.6511, 0.6551, 0.6206, 0.6813, 0.62, 0.6298, 0.6289, 0.6172,
#        0.5682, 0.606, 0.5505, 0.5767, 0.6513, 0.6267, 0.6988, 0.6753,
#        0.6749, 0.6731, 0.6333, 0.6246, 0.691, 0.6716, 0.6692, 0.6604,
#        0.6213, 0.6354, 0.7005, 0.6283, 0.5563, 0.5716, 0.5786, 0.5648,
#        0.6155, 0.5349, 0.4925, 0.5829, 0.4997, 0.5096, 0.5751, 0.6229,
#        0.6357, 0.6216, 0.6154, 0.6337, 0.5858, 0.5935, 0.6328, 0.5372,
#        0.5967, 0.5892, 0.6128, 0.4932, 0.4638, 0.3007, 0.3531, 0.3592,
#        0.3859, 0.372, 0.3365, 0.4096, 0.424, 0.5107, 0.518, 0.5322,
#        0.5174, 0.4873, 0.4944, 0.5616, 0.5147, 0.5226, 0.5403, 0.5674,
#        0.5326, 0.5663, 0.5306, 0.5021, 0.5859, 0.4489, 0.4287, 0.478,
#        0.464, 0.51, 0.4073, 0.3229, 0.2762, 0.309, 0.3336, 0.3364, 0.3755,
# ...

# %%
X['Search Impr. share']=X['Search Impr. share'].replace('<10%',0.09)

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
reg= ExtraTreesRegressor()

# %%
reg.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
feat_importances = pd.Series(reg.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
train=X[0:300]
test=X[300:]

# %%
train_y=y[0:300]
test_y=y[300:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train,train_y, test_size=0.2, random_state=42)

# %%
import xgboost as xgb
xgbst_reg=xgb.XGBRegressor()

# %%
X_train['Search Impr. share']=X_train['Search Impr. share'].replace('<10%',0.09)
# Out:
# C:\Users\vksva\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
X_train['Search Impr. share'].unique()
# Out:
# array([0.2673, 0.6337, 0.6019, 0.4697, 0.3042, 0.6988, 0.6289, 0.4877,
#        0.6357, 0.4263, 0.4433, 0.3897, 0.2754, 0.3191, 0.4417, 0.4756,
#        0.4944, 0.5147, 0.6128, 0.3937, 0.2902, 0.4773, 0.6813, 0.3936,
#        0.5322, 0.5769, 0.3745, 0.3859, 0.7157, 0.701 , 0.2904, 0.309 ,
#        0.4638, 0.1492, 0.6716, 0.6511, 0.3729, 0.4237, 0.4848, 0.4932,
#        0.2792, 0.3007, 0.6753, 0.3901, 0.2846, 0.1668, 0.2851, 0.6206,
#        0.3423, 0.464 , 0.4435, 0.5571, 0.5403, 0.5513, 0.4565, 0.585 ,
#        0.3797, 0.368 , 0.2918, 0.09  , 0.6229, 0.2284, 0.399 , 0.2915,
#        0.3231, 0.3655, 0.6692, 0.486 , 0.3608, 0.3975, 0.4235, 0.4325,
#        0.1956, 0.4343, 0.4262, 0.4332, 0.374 , 0.3324, 0.3573, 0.5297,
#        0.5493, 0.3247, 0.324 , 0.4573, 0.1288, 0.5089, 0.3924, 0.3365,
#        0.6267, 0.5616, 0.4003, 0.4093, 0.2601, 0.5278, 0.4288, 0.4446,
#        0.2455, 0.5892, 0.3136, 0.5226, 0.1858, 0.4372, 0.7029, 0.6246,
# ...

# %%
xgbst_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgbst_reg.score(X_train,y_train)
# Out:
# 0.9999999997077927

# %%
X_test['Search Impr. share'].unique()
# Out:
# array([0.09  , 0.3103, 0.4537, 0.6413, 0.3551, 0.211 , 0.3289, 0.4433,
#        0.5845, 0.3528, 0.4547, 0.6216, 0.2966, 0.5716, 0.3807, 0.266 ,
#        0.3649, 0.15  , 0.3674, 0.3191, 0.518 , 0.428 , 0.4626, 0.3532,
#        0.3755, 0.7005, 0.4874, 0.4065, 0.4827, 0.39  , 0.6551, 0.2855,
#        0.6731, 0.5682, 0.3961, 0.4732, 0.5941, 0.5306, 0.5786, 0.372 ,
#        0.4489, 0.424 , 0.311 , 0.5858, 0.5107, 0.5372, 0.4483, 0.2781,
#        0.4015, 0.2842, 0.3558, 0.3865, 0.3973, 0.4096, 0.3823, 0.4759,
#        0.51  , 0.5859, 0.3713, 0.606 ])

# %%
X_test['Search Impr. share']=X_test['Search Impr. share'].replace('<10%',0.09)
# Out:
# C:\Users\vksva\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
xgbst_reg.score(X_test,y_test)
# Out:
# 0.6202535772609634

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
reg= ExtraTreesRegressor()

# %%
reg.fit(X_train,y_train)
# Out:
# ExtraTreesRegressor()

# %%
feat_importances = pd.Series(reg.feature_importances_, index=X_train.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
df1.columns
# Out:
# Index(['Cost', 'Impressions', 'Clicks', 'CTR', 'Avg. CPC', 'Conversions',
#        'Conv. rate', 'Cost / conv.', 'Search Impr. share',
#        'Search Lost IS (rank)', 'Search Lost IS (budget)', 'Completed Jobs',
#        'Income_y', 'Lead Calls', 'Location Zip_y', 'tech_count',
#        'Avg_job_per_day', 'county_name', 'TMAX', 'TMIN', 'Total Leads',
#        'Total Jobs ', 'Avg Service', 'Avg Install', 'Canceled Jobs_y',
#        'Turn over %', 'Canceled %', 'Avg Sales', 'bookedjob', 'totalcalls',
#        'Booking rate'],
#       dtype='object')

# %%
df2=df[['Completed Jobs', 'Total Leads','tech_count','Income_y','bookedjob', 'Total Jobs ','Lead Calls','TMAX',
        'Avg Install']]

# %%
df2.head()
# Out:
#    Completed Jobs  Total Leads  tech_count  Income_y  bookedjob  Total Jobs   \
# 0              57           10          59  23933.54         49          101
# 1              77            9          40  65232.03         56           89
# 2              55            3          21  26195.32         30           31
# 3               6            2           9    264.00         11           15
# 4              73            8          60  48506.16         54           91
#
#    Lead Calls  TMAX  Avg Install
# 0          60    65  3224.412750
# 1          64    71   965.365854
# 2          58    69  1377.666667
# 3          32    69   406.250000
# 4          62    77  1646.943488

# %%
train=df2[0:300]
test=df2[300:]

# %%
y=train['Income_y']
X=train.drop(['Income_y'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X.values,y.values, test_size=0.2, random_state=42)

# %%
xgbst_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgbst_reg.score(X_train,y_train)
# Out:
# 0.9999998634394192

# %%
xgbst_reg.score(X_test,y_test)
# Out:
# 0.566847202638436

# %%
test.head()
# Out:
#      Completed Jobs  Total Leads  tech_count   Income_y  bookedjob  \
# 300               6            4          12     176.00         17
# 301             111           32          39  114534.21         53
# 302             131           40          61  127412.10         59
# 303             131           40          61  127412.10         59
# 304             131           40          61  127412.10         59
#
#      Total Jobs   Lead Calls  TMAX  Avg Install
# 300           33          30    68     0.000000
# 301          114          67    63  2062.083333
# 302          140          74    72  1688.327612
# 303          140          74    72  1688.327612
# 304          140          74    72  1688.327612

# %%
test.isnull().sum()
# Out:
# Completed Jobs    0
# Total Leads       0
# tech_count        0
# Income_y          0
# bookedjob         0
# Total Jobs        0
# Lead Calls        0
# TMAX              0
# Avg Install       1
# dtype: int64

# %%
test['Avg Install'].median()
# Out:
# 2298.813953488

# %%
test['Avg Install']=test['Avg Install'].fillna(2298.813953488)
# Out:
# C:\Users\vksva\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
y_=test['Income_y']
X_=test.drop(['Income_y'],axis=1)

# %%
X_=X_.values

# %%
y_
# Out:
# 300       176.00
# 301    114534.21
# 302    127412.10
# 303    127412.10
# 304    127412.10
# 305    127412.10
# 306     73107.94
# 307    100335.70
# 308     82920.44
# 309     36992.00
# 310       326.00
# 311     86287.17
# 312     79380.38
# 313    104509.01
# 314     96828.96
# 315    108327.11
# 316     99625.26
# 317     76878.35
# 318     69089.17
# 319    128210.29
# 320    177410.42
# 321     68424.71
# 322    130406.40
# 323     41651.85
# 324       102.95
# 325    121328.92
# 326     94156.55
# 327     93428.49
# 328     73106.96
# 329     62484.03
# 330     50088.00
# 331     45289.92
# 332     95437.44
# 333    100674.86
# 334     55735.08
# 335     86421.80
# 336     86421.80
# 337     86421.80
# 338     86421.80
# 339     41343.95
# 340     15788.00
# 341    128985.55
# 342     93402.16
# 343    176747.02
# 344     32502.40
# 345     55111.85
# 346    133042.85
# 347     88538.89
# 348     66133.39
# 349     67090.81
# Name: Income_y, dtype: float64

# %%
xgbst_reg.score(X_,y_)
# Out:
# 0.06049490451033723

# %%
y_pred=xgbst_reg.predict(X_)

# %%
comp=pd.DataFrame({'Actual':y_,'Predicted':y_pred})

# %%
comp
# Out:
#         Actual      Predicted
# 300     176.00      94.551674
# 301  114534.21  124268.210938
# 302  127412.10  156952.171875
# 303  127412.10  156952.171875
# 304  127412.10  156952.171875
# 305  127412.10  156952.171875
# 306   73107.94   80657.398438
# 307  100335.70  146249.796875
# 308   82920.44  143852.515625
# 309   36992.00   56123.953125
# 310     326.00    1774.314087
# 311   86287.17  117134.218750
# 312   79380.38   82495.054688
# 313  104509.01   37838.257812
# 314   96828.96  104173.585938
# 315  108327.11   93265.218750
# 316   99625.26  121004.851562
# 317   76878.35  149626.531250
# 318   69089.17   31707.804688
# 319  128210.29  140276.359375
# 320  177410.42  232762.531250
# 321   68424.71  110502.648438
# 322  130406.40  139922.750000
# 323   41651.85   61517.144531
# 324     102.95   11103.927734
# 325  121328.92  130662.351562
# 326   94156.55  107363.757812
# 327   93428.49   92169.687500
# 328   73106.96  136839.093750
# 329   62484.03   48910.511719
# ...

# %%
comp.plot()
# Out:
# <AxesSubplot:>

# %%
X_test.shape
# Out:
# (60, 8)

# %%
y_[y_==88538.89]
# Out:
# 347    88538.89
# Name: Income_y, dtype: float64

# %%
from sklearn import metrics

# %%
np.sqrt(metrics.mean_squared_error(y_,y_pred))
# Out:
# 38397.66426768597

# %%
metrics.mean_absolute_error(y_,y_pred)
# Out:
# 31509.932623358156

# %%
import pickle

# %%
filename = 'forecasting.pkl'
pickle.dump(xgbst_reg, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(X_, y_)

# %%
73	8	60	48506.16	54	91	62	77	1646.943488
# Out:
#   File "<ipython-input-78-8e8fce42ecdd>", line 1
#     73	8	60	48506.16	54	91	62	77	1646.943488
#       	^
# SyntaxError: invalid syntax

# %%
new=[[73.0,8.0,60.0,16.0,54.0,91.0,62.0,1646.94]]

new=np.array(new)

# %%
new.shape
# Out:
# (1, 8)

# %%
loaded_model.predict(new)
# Out:
# array([52091.543], dtype=float32)
