# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading csv

df = pd.read_excel('final.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0         Day  Day of week     Cost  Impressions  Clicks     CTR  \
# 0           0  2019-01-02            2  1298.05        44533      54  0.0012
# 1           1  2019-01-03            3  1480.26         2221      59  0.0266
# 2           2  2019-01-04            4  1953.52        36095     110  0.0030
# 3           3  2019-01-05            5  2507.57        18171     123  0.0068
# 4           4  2019-01-06            6  1591.91        15185      88  0.0058
#
#    Avg. CPC  Conversions  Conv. rate  Cost / conv.  Search Impr. share  \
# 0     24.04         15.0      0.0540         86.54              0.3500
# 1     25.09         10.1      0.1712        146.56              0.5233
# 2     17.76         22.0      0.0295         85.93              0.6041
# 3     20.39         29.5      0.0127         85.00              0.7161
# 4     18.09         16.5      0.0087         96.48              0.7447
#
#    Search Lost IS (rank)  Search Lost IS (budget)    Zip    Income        lat  \
# 0                 0.0935                   0.5565  92392  104993.5  34.479332
# 1                 0.1120                   0.3647  90003   40865.2  33.963074
# 2                 0.2028                   0.1931  92201   91188.0  33.711551
# 3                 0.1884                   0.0955  92625   55627.0  33.601873
# 4                 0.2129                   0.0424  92596   12713.0  33.638018
#
#           lng
# 0 -117.397422
# 1 -118.274809
# 2 -116.236141
# 3 -117.866850
# 4 -117.088880

# %%
df= df.drop(['Unnamed: 0','lat','lng'],axis=1)

# %%
df=df.drop(['Cost','Impressions'],axis=1)

# %%
df.head()
# Out:
#           Day  Day of week  Clicks     CTR  Avg. CPC  Conversions  Conv. rate  \
# 0  2019-01-02            2      54  0.0012     24.04         15.0      0.0540
# 1  2019-01-03            3      59  0.0266     25.09         10.1      0.1712
# 2  2019-01-04            4     110  0.0030     17.76         22.0      0.0295
# 3  2019-01-05            5     123  0.0068     20.39         29.5      0.0127
# 4  2019-01-06            6      88  0.0058     18.09         16.5      0.0087
#
#    Cost / conv.  Search Impr. share  Search Lost IS (rank)  \
# 0         86.54              0.3500                 0.0935
# 1        146.56              0.5233                 0.1120
# 2         85.93              0.6041                 0.2028
# 3         85.00              0.7161                 0.1884
# 4         96.48              0.7447                 0.2129
#
#    Search Lost IS (budget)    Zip    Income
# 0                   0.5565  92392  104993.5
# 1                   0.3647  90003   40865.2
# 2                   0.1931  92201   91188.0
# 3                   0.0955  92625   55627.0
# 4                   0.0424  92596   12713.0

# %%
Mean_encoded_subject = df.groupby(['Zip'])['Income'].mean().to_dict() 
  
df['Zip_income'] =  df['Zip'].map(Mean_encoded_subject)

# %%
df= df.drop(['Zip'],axis=1)

# %%
df.head()
# Out:
#           Day  Day of week  Clicks     CTR  Avg. CPC  Conversions  Conv. rate  \
# 0  2019-01-02            2      54  0.0012     24.04         15.0      0.0540
# 1  2019-01-03            3      59  0.0266     25.09         10.1      0.1712
# 2  2019-01-04            4     110  0.0030     17.76         22.0      0.0295
# 3  2019-01-05            5     123  0.0068     20.39         29.5      0.0127
# 4  2019-01-06            6      88  0.0058     18.09         16.5      0.0087
#
#    Cost / conv.  Search Impr. share  Search Lost IS (rank)  \
# 0         86.54              0.3500                 0.0935
# 1        146.56              0.5233                 0.1120
# 2         85.93              0.6041                 0.2028
# 3         85.00              0.7161                 0.1884
# 4         96.48              0.7447                 0.2129
#
#    Search Lost IS (budget)    Income   Zip_income
# 0                   0.5565  104993.5  80940.71000
# 1                   0.3647   40865.2  40865.20000
# 2                   0.1931   91188.0  88801.65125
# 3                   0.0955   55627.0  55627.00000
# 4                   0.0424   12713.0  34731.76000

# %%
df['Day']=pd.to_datetime(df['Day'])
df['day']=pd.to_datetime(df['Day']).dt.day
df['month']=pd.to_datetime(df['Day']).dt.month
df['year']=pd.to_datetime(df['Day']).dt.year
df['quarter']=pd.to_datetime(df['Day']).dt.quarter

# %%
df=df.drop(['Day'],axis=1)

# %%
df.head()
# Out:
#    Day of week  Clicks     CTR  Avg. CPC  Conversions  Conv. rate  \
# 0            2      54  0.0012     24.04         15.0      0.0540
# 1            3      59  0.0266     25.09         10.1      0.1712
# 2            4     110  0.0030     17.76         22.0      0.0295
# 3            5     123  0.0068     20.39         29.5      0.0127
# 4            6      88  0.0058     18.09         16.5      0.0087
#
#    Cost / conv.  Search Impr. share  Search Lost IS (rank)  \
# 0         86.54              0.3500                 0.0935
# 1        146.56              0.5233                 0.1120
# 2         85.93              0.6041                 0.2028
# 3         85.00              0.7161                 0.1884
# 4         96.48              0.7447                 0.2129
#
#    Search Lost IS (budget)    Income   Zip_income  day  month  year  quarter
# 0                   0.5565  104993.5  80940.71000    2      1  2019        1
# 1                   0.3647   40865.2  40865.20000    3      1  2019        1
# 2                   0.1931   91188.0  88801.65125    4      1  2019        1
# 3                   0.0955   55627.0  55627.00000    5      1  2019        1
# 4                   0.0424   12713.0  34731.76000    6      1  2019        1

# %%
train=df[0:650]
cv=df[650:710]
test=df[710:]

# %%
import autofeat

from autofeat import AutoFeatRegressor

# %%
y_train=train['Income']
X_train=train.drop(['Income'],axis=1)

# %%
X_train.shape
# Out:
# (650, 15)

# %%
afreg = AutoFeatRegressor(verbose=1, feateng_steps=2)
df = afreg.fit_transform(X_train,y_train)
# Out:
# [AutoFeat] The 2 step feature engineering process could generate up to 5565 features.
# [AutoFeat] With 650 data points this new feature matrix would use about 0.01 gb of space.
# [feateng] Step 1: transformation of original features
# [feateng]               0/             15 features transformed
# <string>:2: RuntimeWarning: divide by zero encountered in log
# <string>:2: RuntimeWarning: divide by zero encountered in log
# <string>:2: RuntimeWarning: divide by zero encountered in log
# <string>:2: RuntimeWarning: divide by zero encountered in log
# <string>:2: RuntimeWarning: divide by zero encountered in log
# [feateng] Generated 65 transformed features from 15 original features - done.
# [feateng] Step 2: first combination of features
# [feateng]            2500/           3160 feature tuples combined
# C:\Users\vksva\Anaconda3\lib\site-packages\numpy\core\_methods.py:121: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# [feateng] Generated 3097 feature combinations from 3160 original feature tuples - done.
# [feateng] Generated altogether 3197 new features in 2 steps
# [feateng] Removing correlated features, as well as additions at the highest level
# [feateng] Generated a total of 1936 additional features
# [featsel] Scaling data...done.
# [featsel] Feature selection run 1/5
# [featsel] Feature selection run 2/5
# [featsel] Feature selection run 3/5
# [featsel] Feature selection run 4/5
# [featsel] Feature selection run 5/5
# [featsel] 32 features after 5 feature selection runs
# [featsel] 23 features after correlation filtering
# [featsel] 17 features after noise filtering
# [AutoFeat] Computing 16 new features.
# [AutoFeat]    16/   16 new features ...done.
# [AutoFeat] Final dataframe with 31 feature columns (16 new).
# [AutoFeat] Training final regression model.
# [AutoFeat] Trained model: largest coefficients:
# 33146.87657992454
# 23344202.730700 * Convrate**5
# 3162302.571943 * CTR*SearchLostISbudget**3
# -205437.927948 * SearchLostISrank**2/quarter
# -32791.287881 * AvgCPC**3*CTR**3
# 1735.784175 * Conversions*SearchLostISbudget
# -994.436764 * exp(quarter)/AvgCPC
# 118.516119 * sqrt(Zip_income)*exp(SearchLostISbudget)
# -73.621645 * SearchLostISbudget*exp(Dayofweek)
# 25.412241 * exp(Dayofweek)*log(SearchLostISrank)
# 12.936651 * month**3*log(SearchLostISrank)
# -10.859285 * exp(Dayofweek)/SearchImprshare
# 0.228441 * Zip_income
# 0.062441 * Zip_income*log(month)
# 0.020233 * Zip_income*log(AvgCPC)
# -0.001546 * Zip_income*exp(Dayofweek)
# -0.000764 * AvgCPC**5
# [AutoFeat] Final score: 0.7505

# %%
df.head()
# Out:
#    Day of week  Clicks     CTR  Avg. CPC  Conversions  Conv. rate  \
# 0          2.0    54.0  0.0012     24.04         15.0      0.0540
# 1          3.0    59.0  0.0266     25.09         10.1      0.1712
# 2          4.0   110.0  0.0030     17.76         22.0      0.0295
# 3          5.0   123.0  0.0068     20.39         29.5      0.0127
# 4          6.0    88.0  0.0058     18.09         16.5      0.0087
#
#    Cost / conv.  Search Impr. share  Search Lost IS (rank)  \
# 0         86.54              0.3500                 0.0935
# 1        146.56              0.5233                 0.1120
# 2         85.93              0.6041                 0.2028
# 3         85.00              0.7161                 0.1884
# 4         96.48              0.7447                 0.2129
#
#    Search Lost IS (budget)  ...  Zip_income*log(AvgCPC)  \
# 0                   0.5565  ...           257368.722337
# 1                   0.3647  ...           131686.854906
# 2                   0.1931  ...           255477.798457
# 3                   0.0955  ...           167717.885107
# 4                   0.0424  ...           100560.924301
#
#    Conversions*SearchLostISbudget  AvgCPC**3*CTR**3  exp(quarter)/AvgCPC  \
# 0                         8.34750          0.000024             0.113073
# 1                         3.68347          0.297267             0.108341
# 2                         4.24820          0.000151             0.153056
# 3                         2.81725          0.002665             0.133314
# 4                         0.69960          0.001155             0.150264
#
#    Zip_income*log(month)  exp(Dayofweek)/SearchImprshare     AvgCPC**5  \
# 0                    0.0                       21.111589  8.029201e+06
# 1                    0.0                       38.382452  9.942676e+06
# 2                    0.0                       90.379325  1.766912e+06
# 3                    0.0                      207.252003  3.524408e+06
# 4                    0.0                      541.733307  1.937282e+06
#
#     Convrate**5  Conversions**2*Costconv**3  SearchLostISbudget*exp(Dayofweek)
# 0  4.591650e-07                1.458254e+08                           4.112010
# 1  1.470682e-04                3.211361e+08                           7.325195
# 2  2.234138e-08                3.071000e+08                          10.542903
# 3  3.303837e-10                5.344423e+08                          14.173457
# 4  4.984209e-11                2.445005e+08                          17.105381
#
# [5 rows x 31 columns]

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
reg= ExtraTreesRegressor()
reg.fit(df,y_train)
# Out:
# ExtraTreesRegressor()

# %%
feat_importances = pd.Series(reg.feature_importances_, index=df.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
df.columns
# Out:
# Index(['Day of week', 'Cost', 'CTR', 'Avg. CPC', 'Conversions',
#        'Search Impr. share', 'Search Lost IS (rank)',
#        'Search Lost IS (budget)', 'Zip_income', 'day', 'month', 'year',
#        'quarter', 'sqrt(Zip_income)*exp(SearchLostISbudget)',
#        'sqrt(Conversions)*exp(SearchLostISbudget)',
#        'SearchLostISrank*exp(1/AvgCPC)', '(SearchImprshare - 1/quarter)**2',
#        '(Dayofweek**3 - sqrt(Zip_income))**2', 'CTR*SearchLostISbudget**3',
#        'SearchLostISbudget**(3/2)*month**6',
#        'sqrt(log(quarter))*Abs(Zip_income)',
#        'exp(2*Dayofweek)*exp(2*SearchLostISbudget)', 'Dayofweek**6*Zip_income',
#        '(AvgCPC**2 + exp(Dayofweek))**2'],
#       dtype='object')

# %%
import xgboost as xgb

xgbst_reg=xgb.XGBRegressor()

# %%
xgbst_reg.fit(df,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgbst_reg.score(df,y_train)
# Out:
# 0.9999804485958983

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(xgbst_reg,df,y_train,cv=5)

# %%
score.mean()
# Out:
# 0.4272851237922189
